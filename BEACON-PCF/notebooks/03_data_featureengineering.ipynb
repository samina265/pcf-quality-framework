# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt

# %%
product_df1 = pd.read_csv("/workspaces/pcf-quality-framework/BEACON-PCF/data/product_cleaned.csv")

# %%
product_df1.shape
# Out:
# (866, 22)

# %%
product_df1.head()
# Out:
#    Year of reporting *Stage-level CO2e available  \
# 0               2014                         Yes
# 1               2015                         Yes
# 2               2013                         Yes
# 3               2017                         Yes
# 4               2017                         Yes
#
#                   Product name (and functional unit)               Company  \
# 0                           Frosted Flakes(R) Cereal       Kellogg Company
# 1  Frosted Flakes, 23 oz, produced in Lancaster, ...       Kellogg Company
# 2                                       Office Chair             KNOLL INC
# 3                             Multifunction Printers  Konica Minolta, Inc.
# 4                             Multifunction Printers  Konica Minolta, Inc.
#
#   Country (where company is incorporated)    Company's GICS Industry Group  \
# 0                                     USA         Food, Beverage & Tobacco
# ...

# %%
product_df = product_df1.rename(columns={
    "Year of reporting": "Year",
    "Product name (and functional unit)": "Product_Name",
    "Country (where company is incorporated)": "Country",
    "Company's GICS Industry Group": "Industry_Group",
    "Company's GICS Industry": "Industry",
    "*Company's sector": "Sector",
    "Product weight (kg)": "Product_Weight",
    "*Source for product weight": "Weight_Source",
    "Product's carbon footprint (PCF, kg CO2e)": "PCF",
    "*Carbon intensity": "Carbon_Intensity",
    "Protocol used for PCF": "PCF_Protocol",
    "Relative change in PCF vs previous": "Relative_PCF_Change",
    "Company-reported reason for change": "Change_Reason",
    "*Change reason category": "Change_Reason_Category",
    "*Stage-level CO2e available": "Stage_Level_CO2e_Available",
    "*%Upstream estimated from %Operations": "Upstream_Estimated",
    "*Upstream CO2e (fraction of total PCF)": "Upstream_CO2e",
    "*Operations CO2e (fraction of total PCF)": "Operations_CO2e",
    "*Downstream CO2e (fraction of total PCF)": "Downstream_CO2e",
    "*Transport CO2e (fraction of total PCF)": "Transport_CO2e",
    "*EndOfLife CO2e (fraction of total PCF)": "EndOfLife_CO2e"
})

# %% [markdown]
# Features and Target

# %%
product_df.columns.tolist()
# Out:
# ['Year',
#  'Stage_Level_CO2e_Available',
#  'Product_Name',
#  'Company',
#  'Country',
#  'Industry_Group',
#  'Industry',
#  'Sector',
#  'Product_Weight',
#  'Weight_Source',
#  'PCF',
#  'Carbon_Intensity',
#  'PCF_Protocol',
#  'Relative_PCF_Change',
#  'Change_Reason',
#  'Change_Reason_Category',
#  'Upstream_Estimated',
#  'Upstream_CO2e',
#  'Operations_CO2e',
#  'Downstream_CO2e',
#  'Transport_CO2e',
#  'EndOfLife_CO2e']

# %%
target = "PCF"

X = product_df.drop(columns=[target])
y = product_df[target]

# %%
X.select_dtypes(include="number").columns
# Out:
# Index(['Year', 'Product_Weight', 'Carbon_Intensity', 'Upstream_CO2e',
#        'Operations_CO2e', 'Downstream_CO2e', 'Transport_CO2e',
#        'EndOfLife_CO2e'],
#       dtype='str')

# %%
numerical_cols = X.select_dtypes(include=["number"]).columns

# %%
X.select_dtypes(include="object").columns
# Out:
# /tmp/ipykernel_33902/2213039483.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   X.select_dtypes(include="object").columns
# Index(['Stage_Level_CO2e_Available', 'Product_Name', 'Company', 'Country',
#        'Industry_Group', 'Industry', 'Sector', 'Weight_Source', 'PCF_Protocol',
#        'Relative_PCF_Change', 'Change_Reason', 'Change_Reason_Category',
#        'Upstream_Estimated'],
#       dtype='str')

# %%
categorical_cols = X.select_dtypes(include="object").columns
# Out:
# /tmp/ipykernel_33902/3963226579.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = X.select_dtypes(include="object").columns
